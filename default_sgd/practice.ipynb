# %%
import cv2
import glob
import sys
import os
import numpy as np
import tqdm
from sklearn.model_selection import train_test_split
from tensorflow import keras
from functools import partial
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from scipy.signal import savgol_filter
import matplotlib.pyplot as plt

def load_file(path,x,y,x_1,y_1):
    files = glob.glob(path+'./*.jpg')
    if not files:
        print("Chck Phath")
        sys.exit()
    img = []
    for index, i in enumerate(tqdm.tqdm((files))):
        im = cv2.imread(i, cv2.IMREAD_GRAYSCALE)[y:y_1, x:x_1]
        if index == 0:
            ref_img = im
        img.append(np.stack([im, ref_img], axis = 2))
    return np.array(img)

features = load_file('../data/ML/', 211-50, 407-75,211+100,407+75)
target = np.array(pd.read_csv('../data/ML/target.csv', encoding='CP949'))[:,3]
min_max_scaler  = MinMaxScaler()
target = min_max_scaler.fit_transform(target.reshape(-1, 1))
target = savgol_filter(target.flatten(),201,1).reshape(-1, 1)

delete_index = [i for i in range(1,439)]
target = np.delete(target, delete_index, 0)
features = np.delete(features, delete_index, 0)

X_train,  X_valid, y_train, y_valid = train_test_split(features, target, test_size=0.15, random_state=0)
X_train = X_train / 255.0
X_valid = X_valid / 255.0

X_valid,  X_test, y_valid, y_test = train_test_split(X_valid, y_valid, test_size=0.5, random_state=0)

DefaultConv2D = partial(keras.layers.Conv2D,
                        kernel_size=3, activation='relu', padding="SAME")

model = keras.models.Sequential([
    DefaultConv2D(filters=64, input_shape=[150, 150, 2]),
    DefaultConv2D(filters=64),
    keras.layers.MaxPooling2D(pool_size=2),
    DefaultConv2D(filters=128),
    DefaultConv2D(filters=128),
    keras.layers.MaxPooling2D(pool_size=2),
    DefaultConv2D(filters=256),
    DefaultConv2D(filters=256),
    keras.layers.MaxPooling2D(pool_size=2),
    keras.layers.Flatten(),
    keras.layers.Dense(units=128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=64, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=1),
])


model.compile(loss="mse", optimizer='SGD', metrics=["mse"])
history = model.fit(X_train, y_train, epochs=150, validation_data=(X_valid, y_valid))
score = model.evaluate(X_valid, y_valid)

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]
epoch_count = range(1, len(training_loss)+1)


plt.plot(epoch_count, training_loss, "r-")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["training_loss", "test_loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.ylim(0,0.1)
# Out:
# 100%|██████████| 3638/3638 [00:19<00:00, 189.50it/s]
# Train on 2720 samples, validate on 240 samples
# Epoch 1/150
# 2720/2720 [==============================] - 10s 4ms/sample - loss: 0.1151 - mse: 0.1151 - val_loss: 0.0937 - val_mse: 0.0937
# Epoch 2/150
# 2720/2720 [==============================] - 7s 3ms/sample - loss: 0.0964 - mse: 0.0964 - val_loss: 0.0894 - val_mse: 0.0894
# Epoch 3/150
# 2720/2720 [==============================] - 7s 3ms/sample - loss: 0.0904 - mse: 0.0904 - val_loss: 0.0855 - val_mse: 0.0855
# Epoch 4/150
# 2720/2720 [==============================] - 7s 3ms/sample - loss: 0.0835 - mse: 0.0835 - val_loss: 0.0762 - val_mse: 0.0762
# Epoch 5/150
# 2720/2720 [==============================] - 7s 3ms/sample - loss: 0.0691 - mse: 0.0691 - val_loss: 0.0446 - val_mse: 0.0446
# Epoch 6/150
# 2720/2720 [==============================] - 7s 3ms/sample - loss: 0.0401 - mse: 0.0401 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 7/150
# 2720/2720 [==============================] - 7s 3ms/sample - loss: 0.0276 - mse: 0.0276 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 8/150
# 2720/2720 [==============================] - 7s 3ms/sample - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 9/150
# 2720/2720 [==============================] - 7s 3ms/sample - loss: 0.0228 - mse: 0.0228 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 10/150
# 2720/2720 [==============================] - 7s 3ms/sample - loss: 0.0214 - mse: 0.0214 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 11/150
# 2720/2720 [==============================] - 7s 3ms/sample - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 12/150
# 2720/2720 [==============================] - 7s 3ms/sample - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 13/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 14/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 15/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 16/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0152 - mse: 0.0152 - val_loss: 9.2577e-04 - val_mse: 9.2577e-04
# Epoch 17/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0164 - mse: 0.0164 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 18/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 19/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 20/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 21/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 22/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 23/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 24/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 25/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0132 - mse: 0.0132 - val_loss: 7.1524e-04 - val_mse: 7.1524e-04
# Epoch 26/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0129 - mse: 0.0129 - val_loss: 9.1154e-04 - val_mse: 9.1154e-04
# Epoch 27/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 28/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0132 - mse: 0.0132 - val_loss: 7.0847e-04 - val_mse: 7.0847e-04
# Epoch 29/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0116 - mse: 0.0116 - val_loss: 9.9206e-04 - val_mse: 9.9206e-04
# Epoch 30/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 31/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0125 - mse: 0.0125 - val_loss: 6.2934e-04 - val_mse: 6.2934e-04
# Epoch 32/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0120 - mse: 0.0120 - val_loss: 6.7489e-04 - val_mse: 6.7489e-04
# Epoch 33/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 34/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 35/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 36/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0120 - mse: 0.0120 - val_loss: 5.7797e-04 - val_mse: 5.7797e-04
# Epoch 37/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0120 - mse: 0.0120 - val_loss: 3.8018e-04 - val_mse: 3.8018e-04
# Epoch 38/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0112 - mse: 0.0112 - val_loss: 9.9189e-04 - val_mse: 9.9189e-04
# Epoch 39/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 40/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0114 - mse: 0.0114 - val_loss: 6.7792e-04 - val_mse: 6.7792e-04
# Epoch 41/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0112 - mse: 0.0112 - val_loss: 9.0538e-04 - val_mse: 9.0538e-04
# Epoch 42/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0110 - mse: 0.0110 - val_loss: 7.8580e-04 - val_mse: 7.8580e-04
# Epoch 43/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0110 - mse: 0.0110 - val_loss: 5.3131e-04 - val_mse: 5.3131e-04
# Epoch 44/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0104 - mse: 0.0104 - val_loss: 7.5660e-04 - val_mse: 7.5660e-04
# Epoch 45/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0110 - mse: 0.0110 - val_loss: 8.4730e-04 - val_mse: 8.4730e-04
# Epoch 46/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0105 - mse: 0.0105 - val_loss: 7.6224e-04 - val_mse: 7.6224e-04
# Epoch 47/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0110 - mse: 0.0110 - val_loss: 8.6924e-04 - val_mse: 8.6924e-04
# Epoch 48/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0103 - mse: 0.0103 - val_loss: 4.4863e-04 - val_mse: 4.4863e-04
# Epoch 49/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0104 - mse: 0.0104 - val_loss: 7.3395e-04 - val_mse: 7.3395e-04
# Epoch 50/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 51/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0105 - mse: 0.0105 - val_loss: 5.1186e-04 - val_mse: 5.1186e-04
# Epoch 52/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0107 - mse: 0.0107 - val_loss: 8.9467e-04 - val_mse: 8.9467e-04
# Epoch 53/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0101 - mse: 0.0101 - val_loss: 5.6498e-04 - val_mse: 5.6498e-04
# Epoch 54/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 55/150
#  - ETA: 5s - loss: 0.0114 - mse: 0.0114
# Epoch 56/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0101 - mse: 0.0101 - val_loss: 8.5303e-04 - val_mse: 8.5303e-04
# Epoch 57/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0097 - mse: 0.0097 - val_loss: 5.0287e-04 - val_mse: 5.0287e-04
# Epoch 58/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0097 - mse: 0.0097 - val_loss: 6.3498e-04 - val_mse: 6.3498e-04
# Epoch 59/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0095 - mse: 0.0095 - val_loss: 6.3712e-04 - val_mse: 6.3712e-04
# Epoch 60/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0092 - mse: 0.0092 - val_loss: 6.8686e-04 - val_mse: 6.8686e-04
# Epoch 61/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0089 - mse: 0.0089 - val_loss: 6.9742e-04 - val_mse: 6.9742e-04
# Epoch 62/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0094 - mse: 0.0094 - val_loss: 5.7264e-04 - val_mse: 5.7264e-04
# Epoch 63/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0099 - mse: 0.0099 - val_loss: 7.1650e-04 - val_mse: 7.1650e-04
# Epoch 64/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0089 - mse: 0.0089 - val_loss: 4.5691e-04 - val_mse: 4.5691e-04
# Epoch 65/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0093 - mse: 0.0093 - val_loss: 7.2824e-04 - val_mse: 7.2824e-04
# Epoch 66/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0093 - mse: 0.0093 - val_loss: 8.4140e-04 - val_mse: 8.4140e-04
# Epoch 67/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0091 - mse: 0.0091 - val_loss: 5.9992e-04 - val_mse: 5.9992e-04
# Epoch 68/150
#  - ETA: 5s - loss: 0.0103 - mse: 0.0103
# Epoch 69/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0094 - mse: 0.0094 - val_loss: 8.2082e-04 - val_mse: 8.2082e-04
# Epoch 70/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0091 - mse: 0.0091 - val_loss: 8.9104e-04 - val_mse: 8.9104e-04
# Epoch 71/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0092 - mse: 0.0092 - val_loss: 7.0677e-04 - val_mse: 7.0677e-04
# Epoch 72/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0090 - mse: 0.0090 - val_loss: 6.0600e-04 - val_mse: 6.0600e-04
# Epoch 73/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0086 - mse: 0.0086 - val_loss: 6.8552e-04 - val_mse: 6.8552e-04
# Epoch 74/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0100 - mse: 0.0100 - val_loss: 7.5346e-04 - val_mse: 7.5346e-04
# Epoch 75/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0093 - mse: 0.0093 - val_loss: 8.2195e-04 - val_mse: 8.2195e-04
# Epoch 76/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0088 - mse: 0.0088 - val_loss: 3.7359e-04 - val_mse: 3.7359e-04
# Epoch 77/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0085 - mse: 0.0085 - val_loss: 6.2878e-04 - val_mse: 6.2878e-04
# Epoch 78/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0086 - mse: 0.0086 - val_loss: 6.0755e-04 - val_mse: 6.0755e-04
# Epoch 79/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 80/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0088 - mse: 0.0088 - val_loss: 9.9302e-04 - val_mse: 9.9302e-04
# Epoch 81/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0087 - mse: 0.0087 - val_loss: 8.9751e-04 - val_mse: 8.9751e-04
# Epoch 82/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0086 - mse: 0.0086 - val_loss: 8.7366e-04 - val_mse: 8.7366e-04
# Epoch 83/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0086 - mse: 0.0086 - val_loss: 8.0991e-04 - val_mse: 8.0991e-04
# Epoch 84/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0086 - mse: 0.0086 - val_loss: 3.9451e-04 - val_mse: 3.9451e-04
# Epoch 85/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0089 - mse: 0.0089 - val_loss: 9.6230e-04 - val_mse: 9.6230e-04
# Epoch 86/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0088 - mse: 0.0088 - val_loss: 7.1075e-04 - val_mse: 7.1075e-04
# Epoch 87/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0089 - mse: 0.0089 - val_loss: 8.7498e-04 - val_mse: 8.7498e-04
# Epoch 88/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0084 - mse: 0.0084 - val_loss: 9.1285e-04 - val_mse: 9.1285e-04
# Epoch 89/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0086 - mse: 0.0086 - val_loss: 9.0529e-04 - val_mse: 9.0529e-04
# Epoch 90/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0087 - mse: 0.0087 - val_loss: 5.1099e-04 - val_mse: 5.1099e-04
# Epoch 91/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0086 - mse: 0.0086 - val_loss: 5.7069e-04 - val_mse: 5.7069e-04
# Epoch 92/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 7.5416e-04 - val_mse: 7.5416e-04
# Epoch 93/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 6.9389e-04 - val_mse: 6.9389e-04
# Epoch 94/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 6.0629e-04 - val_mse: 6.0629e-04
# Epoch 95/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0086 - mse: 0.0086 - val_loss: 9.4031e-04 - val_mse: 9.4031e-04
# Epoch 96/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0085 - mse: 0.0085 - val_loss: 8.8495e-04 - val_mse: 8.8495e-04
# Epoch 97/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0084 - mse: 0.0084 - val_loss: 5.4967e-04 - val_mse: 5.4967e-04
# Epoch 98/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 99/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0086 - mse: 0.0086 - val_loss: 9.5148e-04 - val_mse: 9.5148e-04
# Epoch 100/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0087 - mse: 0.0087 - val_loss: 5.8443e-04 - val_mse: 5.8443e-04
# Epoch 101/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 6.3307e-04 - val_mse: 6.3307e-04
# Epoch 102/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0083 - mse: 0.0083 - val_loss: 6.4493e-04 - val_mse: 6.4493e-04
# Epoch 103/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 5.9731e-04 - val_mse: 5.9731e-04
# Epoch 104/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0082 - mse: 0.0082 - val_loss: 5.9950e-04 - val_mse: 5.9950e-04
# Epoch 105/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 106/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0085 - mse: 0.0085 - val_loss: 4.6514e-04 - val_mse: 4.6514e-04
# Epoch 107/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 6.2225e-04 - val_mse: 6.2225e-04
# Epoch 108/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0082 - mse: 0.0082 - val_loss: 5.4483e-04 - val_mse: 5.4483e-04
# Epoch 109/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0085 - mse: 0.0085 - val_loss: 7.2199e-04 - val_mse: 7.2199e-04
# Epoch 110/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 5.4557e-04 - val_mse: 5.4557e-04
# Epoch 111/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0084 - mse: 0.0084 - val_loss: 8.6531e-04 - val_mse: 8.6531e-04
# Epoch 112/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 113/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0082 - mse: 0.0082 - val_loss: 6.0997e-04 - val_mse: 6.0997e-04
# Epoch 114/150
#  - ETA: 3s - loss: 0.0080 - mse: 0.0080
# Epoch 115/150
#  - ETA: 4s - loss: 0.0079 - mse: 0.0079
# Epoch 116/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 5.2647e-04 - val_mse: 5.2647e-04
# Epoch 117/150
#  - ETA: 0s - loss: 0.0082 - mse: 0.0082
# Epoch 118/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0080 - mse: 0.0080 - val_loss: 6.0989e-04 - val_mse: 6.0989e-04
# Epoch 119/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0080 - mse: 0.0080 - val_loss: 7.9747e-04 - val_mse: 7.9747e-04
# Epoch 120/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0082 - mse: 0.0082 - val_loss: 8.5893e-04 - val_mse: 8.5893e-04
# Epoch 121/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 9.3061e-04 - val_mse: 9.3061e-04
# Epoch 122/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 7.5170e-04 - val_mse: 7.5170e-04
# Epoch 123/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 7.6722e-04 - val_mse: 7.6722e-04
# Epoch 124/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0077 - mse: 0.0077 - val_loss: 7.6799e-04 - val_mse: 7.6799e-04
# Epoch 125/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0080 - mse: 0.0080 - val_loss: 9.3415e-04 - val_mse: 9.3415e-04
# Epoch 126/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 6.3931e-04 - val_mse: 6.3931e-04
# Epoch 127/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 8.1059e-04 - val_mse: 8.1059e-04
# Epoch 128/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 129/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 7.9898e-04 - val_mse: 7.9898e-04
# Epoch 130/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 6.6862e-04 - val_mse: 6.6862e-04
# Epoch 131/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0080 - mse: 0.0080 - val_loss: 6.7080e-04 - val_mse: 6.7080e-04
# Epoch 132/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 6.1934e-04 - val_mse: 6.1934e-04
# Epoch 133/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 9.5358e-04 - val_mse: 9.5358e-04
# Epoch 134/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 8.5199e-04 - val_mse: 8.5199e-04
# Epoch 135/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 136/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 137/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 138/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0081 - mse: 0.0081 - val_loss: 6.2879e-04 - val_mse: 6.2879e-04
# Epoch 139/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 6.2644e-04 - val_mse: 6.2644e-04
# Epoch 140/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 8.0223e-04 - val_mse: 8.0223e-04
# Epoch 141/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0076 - mse: 0.0076 - val_loss: 6.8358e-04 - val_mse: 6.8358e-04
# Epoch 142/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 7.3802e-04 - val_mse: 7.3802e-04
# Epoch 143/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 7.0773e-04 - val_mse: 7.0773e-04
# Epoch 144/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 6.1082e-04 - val_mse: 6.1082e-04
# Epoch 145/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 146/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 5.6122e-04 - val_mse: 5.6122e-04
# Epoch 147/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 148/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 9.1392e-04 - val_mse: 9.1392e-04
# Epoch 149/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0074 - mse: 0.0074 - val_loss: 8.5819e-04 - val_mse: 8.5819e-04
# Epoch 150/150
# 2720/2720 [==============================] - 8s 3ms/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 7.2033e-04 - val_mse: 7.2033e-04
# 240/240 [==============================] - 0s 1ms/sample - loss: 7.2033e-04 - mse: 7.2033e-04
# (0.0, 0.1)

# %%
predicted_target = model.predict(X_test)

a = [i for i in range(240)]
plt.scatter(a, predicted_target,color='red',label='predict')
plt.scatter(a, y_test,label='target')

plt.legend()

# %%
array = np.hstack((y_test.reshape(-1,1),predicted_target.reshape(-1,1)))
array = array[array[:,1].argsort()]

plt.plot(array[:,0])
plt.plot(array[:,1])

from sklearn.metrics import r2_score
r2_score(y_test, predicted_target)
# Out:
# 0.9922534451279141

# %%
model.save('ml.h5')


np.save('ml_training_loss',training_loss)
np.save('test_loss',test_loss)
